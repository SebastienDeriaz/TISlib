# %% [markdown]
# # Tests

# %% [markdown]
# ## imgLevelAdjust

# %%
import TIS
import numpy as np

# %%
f = np.linspace(0, 128, 9).reshape((3,3))

# %%
TIS.showImage(f)

m = np.array([[10]])

g = TIS.conv2D(f, m, norm=True)

TIS.showImage(g, titles="Type : " + str(g.dtype))
# Out:
# 0.0
# 160.0
# 320.0
# 480.0
# 640.0
# 800.0
# 960.0
# 1120.0
# 1280.0
# (<Figure size 720x720 with 2 Axes>,
#  <AxesSubplot:title={'center':'Type : float64'}, xlabel='3 pixels', ylabel='3 pixels'>)
